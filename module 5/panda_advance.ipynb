# %%
import pandas as pd

# %%
df_xl=pd.read_excel("students.xlsx")
print(df_xl)
df_csv=pd.read_csv("students.csv")
print(df_csv)
# Out:
#     student_id            name  gender department       city  age  cgpa  \
# 0            1   Ayesha Rahman  Female        CSE      Dhaka   21  3.92
# 1            2     Karim Uddin    Male        EEE  Chattogra   22  3.45
# 2            3     Sadia Islam  Female        CSE     Sylhet   20  3.78
# 3            4   Tamim Hossain    Male        BBA      Dhaka   23  2.95
# 4            5    Nabila Akter  Female        CSE   Rajshahi   21  3.66
# 5            6       Rahim Mia    Male         ME     Khulna   22  3.10
# 6            7  Farhana Yasmin  Female        EEE      Dhaka   20  3.88
# 7            8      Imran Khan    Male        BBA  Chattogra   24  3.25
# 8            9   Sumaiya Begum  Female        CSE      Dhaka   19  3.99
# 9           10     Jahid Hasan    Male         ME     Sylhet   23  2.70
# 10          11  Mitu Chowdhury  Female        EEE   Rajshahi   21  3.55
# 11          12     Rifat Ahmed    Male        CSE  Chattogra   22  3.40
# ...
